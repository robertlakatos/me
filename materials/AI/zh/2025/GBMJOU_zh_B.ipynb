# %% [markdown]
# # ZH B csoport - Összesen 10 pont - 90 perc áll rendelkezésre a megoldáshoz

# %% [markdown]
# ## Azonosító adatok

# %%
# NÉV: Mészáros Levente
# NEPTUN KÓD: GBMJOU
# 9 pont

# %% [markdown]
# ## Feladatok

# %% [markdown]
# ### 1. Feladat (1 pont)
#
# <img src=" data:image/png;base64,..." />

# %%
# Válaszodat ide írd!
#                    -19                        gyoker 0. szint
#        -37                  -19               1. szint
#    8        -37        -19         43         2. szint
#  8  -47  -37  -41   -19  -49    43   -26      3. szint

# %%
# 1 pont

# %% [markdown]
# ### 2. Feladat (2 pont)
#
# # Add meg a mélységi keresés implementációját pythonban!

# %%
# A melysegi keresés végző függvény python kódját itt írd meg!
def melysegi_kereses(problem):
    stack = [(Node(problem.initial))]
    explored_states = set()

    while stack:
        curr_node = stack.pop()

        if problem.goal_test(curr_node.state):
            print("Megvan")
            return curr_node

        explored_states.add(curr_node.state)

        stack.extend(child for child in curr_node.expand(problem) if child.state not in explored_states and child not in stack)
        print(curr_node.state)

# %%
# 2 pont

# %% [markdown]
# ### 3. Feladat  (3 pont)
#
# Készíts elő egy tanítási folyamtot egy neurális hálózat számára.

# %%
import pandas as pd
from tqdm import tqdm
import pandas as pd
import numpy as np

# %%
#teendok, adatok szetvalasztasa, shuffle,akar normalizalni is lehetne

fashion = pd.read_csv('fashion.csv')
fashion.head()
#szet kell valasztani a cimkeket es az adatokat data-ra es labelsre, csak nem tudom ennel pontosan hogyan kell labelsnel
data = fashion.values
data = data
#labels = fashion.target ez nem jo
labels = []
#talan minden tombnek az utolso eleme a cimke a databan ezert osszeszedtem a labelsbe
for i in data:
    labels.append(int(i[len(i)-1]))

print(data.shape)
print(len(labels))
print(data)
print(labels)

#data, labels = shuffle(data, labels, random_state = 42)

#ezt csak felirtam
def normalize(x):
    return (x- np.min(x)) / (np.max(x)- np.min(x))
# Out:
# (1000, 785)
# 1000
# [[ 0  0  0 ...  0  0  6]
#  [ 0  0  0 ...  0  0  9]
#  [ 0  0  0 ...  0  0  9]
#  ...
#  [ 0  0  0 ...  0  0  3]
#  [ 0  0  0 ...  0  0  4]
#  [ 0  0  1 ... 70  0  2]]
# ...

# %% [markdown]
# Készítsen egy vizualizációt amivel megjelenti a címkék eloszlását. Mennyi kép van az egyes osztályokban?

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def vizualize(fashion):
    # ToDo:  # ToDo: Ide írd meg a kódot pythonban!
    plt.imshow(fashion)
   

vizualize(fashion)

# %% [markdown]
# Bontsa fel az adathalmazt Tanul és teszt adathalmazra!

# %%
#80 - 20 aranyban kell felbontani az adatot 
test_split_no = int((data[0].shape)[0]* 0.8)

X_train = data[:test_split_no]  # ToDo: Ide írd meg a kódot pythonban!
y_train = labels[:test_split_no]  # ToDo: Ide írd meg a kódot pythonban!

X_test = data[test_split_no:]   # ToDo: Ide írd meg a kódot pythonban!
y_test = labels[test_split_no:]   # ToDo: Ide írd meg a kódot pythonban!

X_train.shape, #y_train.shape, X_test.shape, y_test.shape
# Out:
# ((628, 785),)

# %% [markdown]
# One hot encode-al kódolja le a célváltozólat

# %%
def one_hot_encode(x, num_class):
    # ToDo: Ide írd meg a kódot pythonban!
    return np.eye(num_class)[x]
    #pass

# %%
y_train = one_hot_encode(y_train, 10)
y_test = one_hot_encode(y_test, 10)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((628, 785), (628, 10), (372, 785), (372, 10))

# %%
# 2 pont

# %% [markdown]
# ### 4. Feladat  (2 pont)
#
# A 3. Az előkészített adatokhoz készíts egy neurális hálózatot és tanítsd be.
#
# <img src="  data:image/png;base64,..." />

# %%
#tudom hogy a shape 784 kellene legyen, de a sikertelenul feldolgozott adat miatt muszaj volt igy hagyjam
model = tf.keras.Sequential(
    [
        tf.keras.layers.Input(shape=(785,)),
        tf.keras.layers.Dense(128, activation="relu"),
        tf.keras.layers.Dense(10, activation="softmax")
    ]
)

model.compile(
    optimizer="adam", 
    loss= "categorical_crossentropy",#ToDo: Adja meg a veszteség függvényt, 
    metrics= ["accuracy"]#ToDo: Adja meg a metrikát, 
)

# %% [markdown]
# #### Tanítsa be és értékelje ki a modell a következő paraméterekkel.
#
# - batch_size = 32
# - epoch = 10

# %%
# Train
# ToDo
#tanitas
#ha sikerult volna az adatok feldolgozasa, ez kellene mukodjon normalisan, legalabb lefutott
model.fit(X_train, y_train, epochs = 10, batch_size = 32)
# Out:
# Epoch 1/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2982 - loss: 96.6973
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6390 - loss: 22.0700
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7118 - loss: 14.8481
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7511 - loss: 10.2470
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8104 - loss: 6.3928
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8349 - loss: 3.9947
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8234 - loss: 6.4637
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8683 - loss: 3.2277
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8860 - loss: 2.7282
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8895 - loss: 1.8940

# %%
# Evaluate
# ToDo
model.evaluate(X_test, y_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7504 - loss: 11.4306
# [11.162842750549316, 0.7365591526031494]

# %%
# 2 pont

# %% [markdown]
# ### 5. Feladat (2 pont)
#
# Írd meg a QLearning Agent action és learn metódusát és mutassa be egy tetszőleges példa kóddal annak működését. A következő feltételekkel:
# - A learn metódus gamma paramétere tanítási ciklusonként csökkenjen
# - A action epsilon paramétere ne változzon.

# %%
import random
import numpy as np

class QLearningAgent:
    """
    A Q-learning ügynökünket képviselő osztály
    """
    def __init__(self, n_states_row,  n_states_cols, n_actions, learning_rate):
        self.n_states_row = n_states_row
        self.n_states_cols = n_states_cols
        self.n_actions = n_actions
        self.learning_rate = learning_rate
        
        self.q_table = np.zeros((self.n_states_row, self.n_states_cols, n_actions))
    
    def act(self, state_row, state_col, epsilon):
        # ToDo: Ide írd meg au action módszert.
        random_int = random.uniform(0,1)
        if random_int > epsilon:
            action = np.argmax(self.q_table[state_row][state_col])
        else:
            action = random.randint(0, self.n_actions - 1)
        return action
        #return NotImplementedError()
    
    def learn(self, state_row, state_col, action, reward, new_state_row, new_state_col, gamma):        
        # ToDo: Ide írd meg a learn módszert.
        old_value = self.q_table[state_row][state_col][action]
        new_estimate = reward + gamma * max(self.q_table[new_state_row][new_state_col])
        self.q_table[state_row][state_col][action] = old_value + self.learning_rate* (new_estimate- old_value)
        #gamma csokkentesere proba
        self.gamma *= 0,99
        
        #return NotImplementedError()

# %%
# 2 pont
